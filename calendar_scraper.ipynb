# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

# %%
url = "https://www.ccny.cuny.edu/registrar/fall"

response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

print(soup.title)
# Out:
# <title>Fall 2021 Academic Calendar | The City College of New York</title>

# %%
rows = soup.find_all("tr")

print(len(rows))
# Out:
# 37

# %%
dates = []
dows = []
texts = []

for row in rows:
    cols = row.find_all("td")

    if len(cols) >= 3:
        date = cols[0].text.strip()
        dow = cols[1].text.strip()
        text = cols[2].text.strip()

        dates.append(date)
        dows.append(dow)
        texts.append(text)

# %%
df = pd.DataFrame({
    "date": dates,
    "dow": dows,
    "text": texts
})

# %%
df = df.set_index("date")

df.head()
# Out:
#                                 dow  \
# date
# August 01                    Sunday
# August 18                 Wednesday
# August 24                   Tuesday
# August 25                 Wednesday
# August 25 - 31  Wednesday - Tuesday
#
#                                                              text
# date
# August 01       Application for degree for January and Februar...
# August 18                      Last day to apply for Study Abroad
# August 24       Last day of Registration;\n\t\t\tLast day to f...
# August 25       Start of Fall Term;\n\t\t\tClasses begin;\n\t\...
# August 25 - 31          Change of program period; late fees apply

# %%
df.to_csv("ccny_fall_2021_calendar.csv")

# %%
import os
os.getcwd()
# Out:
# '/Users/dianalucero/Developer/School/2026-Spring/csc46000/HW3'

# %%
os.listdir()
# Out:
# ['Untitled1.ipynb',
#  'anaconda_projects',
#  'Untitled.ipynb',
#  'ccny_fall_2021_calendar.csv',
#  '.ipynb_checkpoints',
#  'calendar_scraper.ipynb']

# %%
df.to_csv("ccny_fall_2021_calendar.csv", index=True)
